# %% [markdown]
# # 数模模板
#
# 这是比赛用的起始 notebook。先把题意、数据、模型、结果分开记录，别一上来就写代码。

# %% [markdown]
# ## 1. 题目拆解
#
# - 每一问的目标
# - 输入数据
# - 输出结果
# - 评价指标
# - 约束条件
# - 需要的图表

# %%
from pathlib import Path
import sys


def find_repo_root(start: Path | None = None) -> Path:
    start = (start or Path.cwd()).resolve()
    for path in [start, *start.parents]:
        if (path / 'requirements.txt').exists():
            return path
    raise FileNotFoundError('Cannot locate repository root.')


ROOT = find_repo_root()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))

from src.config import RAW_DIR, PROCESSED_DIR, FIGURES_DIR, REPORTS_DIR, RESULTS_DIR

ROOT, RAW_DIR, PROCESSED_DIR, FIGURES_DIR, REPORTS_DIR, RESULTS_DIR

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
plt.rcParams['figure.dpi'] = 150
plt.rcParams['axes.unicode_minus'] = False

print('Ready for modeling.')

# %% [markdown]
# ## 2. 数据检查
#
# 先做缺失值、异常值、分布、相关性，再决定模型，不要反着来。

# %%
# df = pd.read_excel(RAW_DIR / 'your_data.xlsx')
# df.head()
# df.info()
# df.describe(include='all')

# %% [markdown]
# ## 3. 建模记录
#
# 记录：假设、模型、参数、结果、误差分析、灵敏度分析。

# %%
# 在这里放 baseline 模型
# 在这里放改进模型
# 在这里放评价指标和可视化

# %% [markdown]
# ## 4. 论文输出
#
# - 图表编号
# - 表格编号
# - 摘要
# - 结论
# - 局限性
